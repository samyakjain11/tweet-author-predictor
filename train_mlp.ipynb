# %%
import math

import numpy as np
import pandas as pd

import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# if this fails, open terminal (on Linux, Mac) or Anaconda Prompt (windows)
# and run:
# conda install -c huggingface transformers
from transformers import AutoModel, AutoTokenizer

# %%
tweets_df = pd.read_csv("data/tweets.csv")
tweets_df
# Out:
#           author                                            content country  \
# 0      katyperry  Is history repeating itself...?#DONTNORMALIZEH...     NaN
# 1      katyperry  @barackobama Thank you for your incredible gra...     NaN
# 2      katyperry                Life goals. https://t.co/XIn1qKMKQl     NaN
# 3      katyperry            Me right now 🙏🏻 https://t.co/gW55C1wrwd     NaN
# 4      katyperry  SISTERS ARE DOIN' IT FOR THEMSELVES! 🙌🏻💪🏻❤️ ht...     NaN
# ...          ...                                                ...     ...
# 52537   ddlovato               Life couldn't be better right now. 😊     NaN
# 52538   ddlovato  First Monday back in action. I'd say 21.6 mile...     NaN
# 52539   ddlovato  Crime shows, buddy, snuggles = the perfect Sun...     NaN
# 52540   ddlovato                          ❄️ http://t.co/sHCFdPpGPa     NaN
# 52541   ddlovato                      ❤️❄️✈️ http://t.co/ixmB5lv17Z     NaN
#
#               date_time            id language  latitude  longitude  \
# 0      12/01/2017 19:52  8.196330e+17       en       NaN        NaN
# 1      11/01/2017 08:38  8.191010e+17       en       NaN        NaN
# 2      11/01/2017 02:52  8.190140e+17       en       NaN        NaN
# 3      11/01/2017 02:44  8.190120e+17       en       NaN        NaN
# 4      10/01/2017 05:22  8.186890e+17       en       NaN        NaN
# ...                 ...           ...      ...       ...        ...
# 52537  06/01/2015 23:10  5.526030e+17       en       NaN        NaN
# 52538  06/01/2015 02:17  5.522880e+17       en       NaN        NaN
# 52539  05/01/2015 03:42  5.519470e+17       en       NaN        NaN
# 52540  05/01/2015 00:06  5.518920e+17      und       NaN        NaN
# 52541  05/01/2015 00:02  5.518910e+17      und       NaN        NaN
#
#        number_of_likes  number_of_shares
# 0                 7900              3472
# 1                 3689              1380
# 2                10341              2387
# 3                10774              2458
# 4                17620              4655
# ...                ...               ...
# 52537            32799             23796
# 52538            21709             12511
# 52539            25269             15583
# 52540            15985             10456
# 52541            16193             10822
#
# [52542 rows x 10 columns]

# %%
unique_people = tweets_df['author'].unique()
print(unique_people)
NUM_CLASSES = len(unique_people)

# assign each person a number
id_to_person = {i: unique_people[i] for i in range(len(unique_people))}
person_to_id = {v:k for k,v in id_to_person.items()}

# create a column of author ids
tweets_df['author_id'] = tweets_df['author'].apply(lambda x: person_to_id[x])
# Out:
# ['katyperry' 'justinbieber' 'taylorswift13' 'BarackObama' 'rihanna'
#  'YouTube' 'ladygaga' 'TheEllenShow' 'Twitter' 'jtimberlake'
#  'KimKardashian' 'britneyspears' 'Cristiano' 'selenagomez' 'cnnbrk'
#  'jimmyfallon' 'ArianaGrande' 'shakira' 'instagram' 'ddlovato']

# %%
tweets_df
# Out:
#           author                                            content country  \
# 0      katyperry  Is history repeating itself...?#DONTNORMALIZEH...     NaN
# 1      katyperry  @barackobama Thank you for your incredible gra...     NaN
# 2      katyperry                Life goals. https://t.co/XIn1qKMKQl     NaN
# 3      katyperry            Me right now 🙏🏻 https://t.co/gW55C1wrwd     NaN
# 4      katyperry  SISTERS ARE DOIN' IT FOR THEMSELVES! 🙌🏻💪🏻❤️ ht...     NaN
# ...          ...                                                ...     ...
# 52537   ddlovato               Life couldn't be better right now. 😊     NaN
# 52538   ddlovato  First Monday back in action. I'd say 21.6 mile...     NaN
# 52539   ddlovato  Crime shows, buddy, snuggles = the perfect Sun...     NaN
# 52540   ddlovato                          ❄️ http://t.co/sHCFdPpGPa     NaN
# 52541   ddlovato                      ❤️❄️✈️ http://t.co/ixmB5lv17Z     NaN
#
#               date_time            id language  latitude  longitude  \
# 0      12/01/2017 19:52  8.196330e+17       en       NaN        NaN
# 1      11/01/2017 08:38  8.191010e+17       en       NaN        NaN
# 2      11/01/2017 02:52  8.190140e+17       en       NaN        NaN
# 3      11/01/2017 02:44  8.190120e+17       en       NaN        NaN
# 4      10/01/2017 05:22  8.186890e+17       en       NaN        NaN
# ...                 ...           ...      ...       ...        ...
# 52537  06/01/2015 23:10  5.526030e+17       en       NaN        NaN
# 52538  06/01/2015 02:17  5.522880e+17       en       NaN        NaN
# 52539  05/01/2015 03:42  5.519470e+17       en       NaN        NaN
# 52540  05/01/2015 00:06  5.518920e+17      und       NaN        NaN
# 52541  05/01/2015 00:02  5.518910e+17      und       NaN        NaN
#
#        number_of_likes  number_of_shares  author_id
# 0                 7900              3472          0
# 1                 3689              1380          0
# 2                10341              2387          0
# 3                10774              2458          0
# 4                17620              4655          0
# ...                ...               ...        ...
# 52537            32799             23796         19
# 52538            21709             12511         19
# 52539            25269             15583         19
# 52540            15985             10456         19
# 52541            16193             10822         19
#
# [52542 rows x 11 columns]

# %%
class TweetDataset(Dataset):
    def __init__(self, df):
        print('making tokenizer...')
        self.tokenizer = AutoTokenizer.from_pretrained("vinai/bertweet-base", use_fast=False)
        print('making bert...')
        self.bertweet = AutoModel.from_pretrained("vinai/bertweet-base")
        
        print('tokenizing inputs...')
        self.inputs = self.tokenizer(list(df['content']), return_tensors="pt", padding=True, truncation=True)
        
        # Run BERT forward pass to get embeddings
        print('running BERT to get embeddings...')
        with torch.no_grad():
            features = self.bertweet(self.inputs.input_ids)
        
        self.embeddings = features.pooler_output
        self.labels = torch.tensor(df['author_id'].values).long()

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        
        x = self.embeddings[idx]
        y = self.labels[idx]
        
        return x, y

# %%
# shuffle the df
np.random.seed(7)
df_full = tweets_df.sample(frac=1.0)

# only do 1000/1000 for the sake of time
n_train = 1000
n_test = 1000

df_train = df_full[:n_train]
df_test = df_full[n_train:n_train+n_test]

ds_train = TweetDataset(df_train)
ds_test = TweetDataset(df_test)
# Out:
# making tokenizer...
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# making bert...
# Some weights of the model checkpoint at vinai/bertweet-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizing inputs...
# running BERT to get embeddings...
# making tokenizer...
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# making bert...
# Some weights of the model checkpoint at vinai/bertweet-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizing inputs...
# running BERT to get embeddings...

# %%
torch.manual_seed(7)

mlp = torch.nn.Sequential(
    torch.nn.Linear(768, 100),
    torch.nn.ReLU(),
    torch.nn.Linear(100, 100),
    torch.nn.ReLU(),
    torch.nn.Linear(100, NUM_CLASSES),
    torch.nn.Softmax(dim=1)
)

# %%
optimizer = torch.optim.Adam(mlp.parameters(), lr=1e-3)
loss_f = torch.nn.CrossEntropyLoss()

# %%
def get_accuracy(ds):
    num_correct = 0

    batch_start = 0
    batch_end = batch_start + batch_size
    print_counter = print_frequency
    while batch_start < len(ds):
        # Grab the batch from the dataset
        x, y = ds[batch_start:batch_end]

        # Forward pass
        with torch.no_grad():
            y_pred = mlp(x)

        # Gets the number of correct predictions
        num_correct += (torch.argmax(y_pred, dim=1) == y).numpy().sum()

        # Update batch parameters
        batch_start = batch_end
        batch_end = batch_start + batch_size
    
    return num_correct / len(ds)

# %%
# Randomly shuffle the indices
idxs = np.arange(len(ds_train))
np.random.shuffle(idxs)

# %%
mlp.train()
epochs = 100
batch_size = 64

# print every these number of batches
print_frequency = 5
print_counter = print_frequency

# Train loop
for epoch in range(epochs):
    batch_start = 0
    batch_end = batch_start + batch_size
    while batch_start < len(ds_train):
        # Grab the batch from the dataset
        idxs_batch = idxs[batch_start:batch_end]
        x, y = ds_train[idxs_batch]
               
        # Forward pass
        optimizer.zero_grad()
        y_pred = mlp(x)

        # Compute Loss
        ### TODO: your code here. Hint: how do we use loss_f? See Pytorch
        # documentation for examples.
        loss = loss_f(y_pred, y)
        
        print_counter -= 1
        if print_counter <= 0:
            print_counter = print_frequency
            
            # Figure out which batch we are on
            batch_num = batch_start // batch_size
            print(f'Epoch {epoch}, Batch {batch_num}. Train loss: {loss.item()}')
        
        # Backward pass
        ### TODO: your code here. Hint: we need to do backpropogation and then
        # update parameters using the optimizer. Look up some examples of how to
        # to do this or go to Pytorch documentation.
        loss.backward()
        optimizer.step()

        
        # Update batch parameters
        batch_start = batch_end
        batch_end = batch_start + batch_size
    
    print('\n----')
    
    train_acc = get_accuracy(ds_train)
    print(f'Train Acc on Epoch {epoch}:', train_acc)
    
    test_acc = get_accuracy(ds_test)
    print(f'Test Acc on Epoch {epoch}:', test_acc)
    
    print('----')
# Out:
# 069458
# Epoch 12, Batch 7. Train loss: 2.9848451614379883
# Epoch 12, Batch 12. Train loss: 2.9523069858551025
#
# ----
# Train Acc on Epoch 12: 0.09
# Test Acc on Epoch 12: 0.087
# ----
# Epoch 13, Batch 1. Train loss: 2.996501922607422
# Epoch 13, Batch 6. Train loss: 2.978071928024292
# Epoch 13, Batch 11. Train loss: 2.987680435180664
#
# ----
# Train Acc on Epoch 13: 0.11
# Test Acc on Epoch 13: 0.107
# ----
# Epoch 14, Batch 0. Train loss: 2.9788246154785156
# Epoch 14, Batch 5. Train loss: 2.964968204498291
# Epoch 14, Batch 10. Train loss: 2.996135950088501
# Epoch 14, Batch 15. Train loss: 2.9613277912139893
#
# ----
# Train Acc on Epoch 14: 0.118
# Test Acc on Epoch 14: 0.112
# ----
# Epoch 15, Batch 4. Train loss: 2.9641940593719482
# Epoch 15, Batch 9. Train loss: 2.9627768993377686
# Epoch 15, Batch 14. Train loss: 2.967087507247925
#
# ----
# Train Acc on Epoch 15: 0.121
# Test Acc on Epoch 15: 0.113
# ----
# Epoch 16, Batch 3. Train loss: 2.950817584991455
# Epoch 16, Batch 8. Train loss: 2.9121253490448
# Epoch 16, Batch 13. Train loss: 2.9674034118652344
#
# ----
# Train Acc on Epoch 16: 0.127
# Test Acc on Epoch 16: 0.11
# ----
# Epoch 17, Batch 2. Train loss: 2.9779677391052246
# Epoch 17, Batch 7. Train loss: 2.976813316345215
# Epoch 17, Batch 12. Train loss: 2.9270238876342773
#
# ----
# Train Acc on Epoch 17: 0.126
# Test Acc on Epoch 17: 0.108
# ----
# Epoch 18, Batch 1. Train loss: 3.001490831375122
# Epoch 18, Batch 6. Train loss: 2.9328012466430664
# Epoch 18, Batch 11. Train loss: 2.9727652072906494
#
# ----
# Train Acc on Epoch 18: 0.129
# Test Acc on Epoch 18: 0.104
# ----
# Epoch 19, Batch 0. Train loss: 2.9708752632141113
# Epoch 19, Batch 5. Train loss: 2.9396495819091797
# Epoch 19, Batch 10. Train loss: 2.991321325302124
# Epoch 19, Batch 15. Train loss: 2.964977979660034
#
# ----
# Train Acc on Epoch 19: 0.13
# Test Acc on Epoch 19: 0.106
# ----
# Epoch 20, Batch 4. Train loss: 2.9335689544677734
# Epoch 20, Batch 9. Train loss: 2.9392220973968506
# Epoch 20, Batch 14. Train loss: 2.9505481719970703
#
# ----
# Train Acc on Epoch 20: 0.136
# Test Acc on Epoch 20: 0.106
# ----
# Epoch 21, Batch 3. Train loss: 2.93461275100708
# Epoch 21, Batch 8. Train loss: 2.8784193992614746
# Epoch 21, Batch 13. Train loss: 2.9556925296783447
#
# ----
# Train Acc on Epoch 21: 0.131
# Test Acc on Epoch 21: 0.107
# ----
# Epoch 22, Batch 2. Train loss: 2.964510202407837
# Epoch 22, Batch 7. Train loss: 2.9646687507629395
# Epoch 22, Batch 12. Train loss: 2.902508020401001
#
# ----
# Train Acc on Epoch 22: 0.137
# Test Acc on Epoch 22: 0.107
# ----
# Epoch 23, Batch 1. Train loss: 3.0015406608581543
# Epoch 23, Batch 6. Train loss: 2.9141924381256104
# Epoch 23, Batch 11. Train loss: 2.9689204692840576
#
# ----
# Train Acc on Epoch 23: 0.133
# Test Acc on Epoch 23: 0.108
# ----
# Epoch 24, Batch 0. Train loss: 2.957486152648926
# Epoch 24, Batch 5. Train loss: 2.914382219314575
# Epoch 24, Batch 10. Train loss: 2.9851222038269043
# Epoch 24, Batch 15. Train loss: 2.954664468765259
#
# ----
# Train Acc on Epoch 24: 0.14
# Test Acc on Epoch 24: 0.109
# ----
# Epoch 25, Batch 4. Train loss: 2.918046474456787
# Epoch 25, Batch 9. Train loss: 2.924071788787842
# Epoch 25, Batch 14. Train loss: 2.9439003467559814
#
# ----
# Train Acc on Epoch 25: 0.136
# Test Acc on Epoch 25: 0.111
# ----
# Epoch 26, Batch 3. Train loss: 2.9171218872070312
# Epoch 26, Batch 8. Train loss: 2.860992670059204
# Epoch 26, Batch 13. Train loss: 2.944074869155884
#
# ----
# Train Acc on Epoch 26: 0.142
# Test Acc on Epoch 26: 0.112
# ----
# Epoch 27, Batch 2. Train loss: 2.953564405441284
# Epoch 27, Batch 7. Train loss: 2.9511094093322754
# Epoch 27, Batch 12. Train loss: 2.8845152854919434
#
# ----
# Train Acc on Epoch 27: 0.138
# Test Acc on Epoch 27: 0.109
# ----
# Epoch 28, Batch 1. Train loss: 3.0030534267425537
# Epoch 28, Batch 6. Train loss: 2.9092931747436523
# Epoch 28, Batch 11. Train loss: 2.9677932262420654
#
# ----
# Train Acc on Epoch 28: 0.151
# Test Acc on Epoch 28: 0.116
# ----
# Epoch 29, Batch 0. Train loss: 2.9539639949798584
# Epoch 29, Batch 5. Train loss: 2.9026379585266113
# Epoch 29, Batch 10. Train loss: 2.9700913429260254
# Epoch 29, Batch 15. Train loss: 2.9694015979766846
#
# ----
# Train Acc on Epoch 29: 0.143
# Test Acc on Epoch 29: 0.109
# ----
# Epoch 30, Batch 4. Train loss: 2.8943543434143066
# Epoch 30, Batch 9. Train loss: 2.910245656967163
# Epoch 30, Batch 14. Train loss: 2.934696912765503
#
# ----
# Train Acc on Epoch 30: 0.159
# Test Acc on Epoch 30: 0.118
# ----
# Epoch 31, Batch 3. Train loss: 2.912510395050049
# Epoch 31, Batch 8. Train loss: 2.8430559635162354
# Epoch 31, Batch 13. Train loss: 2.9445927143096924
#
# ----
# Train Acc on Epoch 31: 0.151
# Test Acc on Epoch 31: 0.112
# ----
# Epoch 32, Batch 2. Train loss: 2.9514687061309814
# Epoch 32, Batch 7. Train loss: 2.932037830352783
# Epoch 32, Batch 12. Train loss: 2.883110523223877
#
# ----
# Train Acc on Epoch 32: 0.161
# Test Acc on Epoch 32: 0.118
# ----
# Epoch 33, Batch 1. Train loss: 2.9881186485290527
# Epoch 33, Batch 6. Train loss: 2.898757219314575
# Epoch 33, Batch 11. Train loss: 2.960989475250244
#
# ----
# Train Acc on Epoch 33: 0.158
# Test Acc on Epoch 33: 0.114
# ----
# Epoch 34, Batch 0. Train loss: 2.9305944442749023
# Epoch 34, Batch 5. Train loss: 2.905806541442871
# Epoch 34, Batch 10. Train loss: 2.975274085998535
# Epoch 34, Batch 15. Train loss: 2.9266817569732666
#
# ----
# Train Acc on Epoch 34: 0.165
# Test Acc on Epoch 34: 0.119
# ----
# Epoch 35, Batch 4. Train loss: 2.903170108795166
# Epoch 35, Batch 9. Train loss: 2.9016525745391846
# Epoch 35, Batch 14. Train loss: 2.9319887161254883
#
# ----
# Train Acc on Epoch 35: 0.158
# Test Acc on Epoch 35: 0.112
# ----
# Epoch 36, Batch 3. Train loss: 2.9025111198425293
# Epoch 36, Batch 8. Train loss: 2.8349716663360596
# Epoch 36, Batch 13. Train loss: 2.938554286956787
#
# ----
# Train Acc on Epoch 36: 0.169
# Test Acc on Epoch 36: 0.12
# ----
# Epoch 37, Batch 2. Train loss: 2.9423863887786865
# Epoch 37, Batch 7. Train loss: 2.932548999786377
# Epoch 37, Batch 12. Train loss: 2.8748552799224854
#
# ----
# Train Acc on Epoch 37: 0.157
# Test Acc on Epoch 37: 0.116
# ----
# Epoch 38, Batch 1. Train loss: 2.994743824005127
# Epoch 38, Batch 6. Train loss: 2.9009721279144287
# Epoch 38, Batch 11. Train loss: 2.962104558944702
#
# ----
# Train Acc on Epoch 38: 0.173
# Test Acc on Epoch 38: 0.118
# ----
# Epoch 39, Batch 0. Train loss: 2.9394233226776123
# Epoch 39, Batch 5. Train loss: 2.8828587532043457
# Epoch 39, Batch 10. Train loss: 2.964299201965332
# Epoch 39, Batch 15. Train loss: 2.9455175399780273
#
# ----
# Train Acc on Epoch 39: 0.161
# Test Acc on Epoch 39: 0.117
# ----
# Epoch 40, Batch 4. Train loss: 2.8846476078033447
# Epoch 40, Batch 9. Train loss: 2.8916053771972656
# Epoch 40, Batch 14. Train loss: 2.921396493911743
#
# ----
# Train Acc on Epoch 40: 0.176
# Test Acc on Epoch 40: 0.126
# ----
# Epoch 41, Batch 3. Train loss: 2.889190196990967
# Epoch 41, Batch 8. Train loss: 2.8251843452453613
# Epoch 41, Batch 13. Train loss: 2.9363417625427246
#
# ----
# Train Acc on Epoch 41: 0.164
# Test Acc on Epoch 41: 0.117
# ----
# Epoch 42, Batch 2. Train loss: 2.936993360519409
# Epoch 42, Batch 7. Train loss: 2.9137704372406006
# Epoch 42, Batch 12. Train loss: 2.8804407119750977
#
# ----
# Train Acc on Epoch 42: 0.177
# Test Acc on Epoch 42: 0.127
# ----
# Epoch 43, Batch 1. Train loss: 2.979243278503418
# Epoch 43, Batch 6. Train loss: 2.8893396854400635
# Epoch 43, Batch 11. Train loss: 2.9504764080047607
#
# ----
# Train Acc on Epoch 43: 0.166
# Test Acc on Epoch 43: 0.121
# ----
# Epoch 44, Batch 0. Train loss: 2.9092209339141846
# Epoch 44, Batch 5. Train loss: 2.875054121017456
# Epoch 44, Batch 10. Train loss: 2.9676296710968018
# Epoch 44, Batch 15. Train loss: 2.9123778343200684
#
# ----
# Train Acc on Epoch 44: 0.175
# Test Acc on Epoch 44: 0.12
# ----
# Epoch 45, Batch 4. Train loss: 2.8867459297180176
# Epoch 45, Batch 9. Train loss: 2.8887765407562256
# Epoch 45, Batch 14. Train loss: 2.917247772216797
#
# ----
# Train Acc on Epoch 45: 0.165
# Test Acc on Epoch 45: 0.119
# ----
# Epoch 46, Batch 3. Train loss: 2.888533353805542
# Epoch 46, Batch 8. Train loss: 2.8316497802734375
# Epoch 46, Batch 13. Train loss: 2.934544324874878
#
# ----
# Train Acc on Epoch 46: 0.175
# Test Acc on Epoch 46: 0.12
# ----
# Epoch 47, Batch 2. Train loss: 2.9105374813079834
# Epoch 47, Batch 7. Train loss: 2.9082746505737305
# Epoch 47, Batch 12. Train loss: 2.8628427982330322
#
# ----
# Train Acc on Epoch 47: 0.171
# Test Acc on Epoch 47: 0.121
# ----
# Epoch 48, Batch 1. Train loss: 2.976332664489746
# Epoch 48, Batch 6. Train loss: 2.8878235816955566
# Epoch 48, Batch 11. Train loss: 2.9274518489837646
#
# ----
# Train Acc on Epoch 48: 0.177
# Test Acc on Epoch 48: 0.124
# ----
# Epoch 49, Batch 0. Train loss: 2.90048885345459
# Epoch 49, Batch 5. Train loss: 2.8662331104278564
# Epoch 49, Batch 10. Train loss: 2.9506828784942627
# Epoch 49, Batch 15. Train loss: 2.911890745162964
#
# ----
# Train Acc on Epoch 49: 0.182
# Test Acc on Epoch 49: 0.123
# ----
# Epoch 50, Batch 4. Train loss: 2.8701322078704834
# Epoch 50, Batch 9. Train loss: 2.8768186569213867
# Epoch 50, Batch 14. Train loss: 2.9057207107543945
#
# ----
# Train Acc on Epoch 50: 0.178
# Test Acc on Epoch 50: 0.124
# ----
# Epoch 51, Batch 3. Train loss: 2.87042236328125
# Epoch 51, Batch 8. Train loss: 2.821378231048584
# Epoch 51, Batch 13. Train loss: 2.9345004558563232
#
# ----
# Train Acc on Epoch 51: 0.182
# Test Acc on Epoch 51: 0.123
# ----
# Epoch 52, Batch 2. Train loss: 2.8958804607391357
# Epoch 52, Batch 7. Train loss: 2.8984851837158203
# Epoch 52, Batch 12. Train loss: 2.857296943664551
#
# ----
# Train Acc on Epoch 52: 0.184
# Test Acc on Epoch 52: 0.125
# ----
# Epoch 53, Batch 1. Train loss: 2.9683783054351807
# Epoch 53, Batch 6. Train loss: 2.8861708641052246
# Epoch 53, Batch 11. Train loss: 2.915475845336914
#
# ----
# Train Acc on Epoch 53: 0.19
# Test Acc on Epoch 53: 0.123
# ----
# Epoch 54, Batch 0. Train loss: 2.8801229000091553
# Epoch 54, Batch 5. Train loss: 2.858698606491089
# Epoch 54, Batch 10. Train loss: 2.9400951862335205
# Epoch 54, Batch 15. Train loss: 2.9051573276519775
#
# ----
# Train Acc on Epoch 54: 0.189
# Test Acc on Epoch 54: 0.126
# ----
# Epoch 55, Batch 4. Train loss: 2.8632047176361084
# Epoch 55, Batch 9. Train loss: 2.874990224838257
# Epoch 55, Batch 14. Train loss: 2.8943562507629395
#
# ----
# Train Acc on Epoch 55: 0.189
# Test Acc on Epoch 55: 0.129
# ----
# Epoch 56, Batch 3. Train loss: 2.857327461242676
# Epoch 56, Batch 8. Train loss: 2.8093936443328857
# Epoch 56, Batch 13. Train loss: 2.934234142303467
#
# ----
# Train Acc on Epoch 56: 0.196
# Test Acc on Epoch 56: 0.133
# ----
# Epoch 57, Batch 2. Train loss: 2.8801424503326416
# Epoch 57, Batch 7. Train loss: 2.883694887161255
# Epoch 57, Batch 12. Train loss: 2.855515241622925
#
# ----
# Train Acc on Epoch 57: 0.2
# Test Acc on Epoch 57: 0.133
# ----
# Epoch 58, Batch 1. Train loss: 2.9605777263641357
# Epoch 58, Batch 6. Train loss: 2.877166509628296
# Epoch 58, Batch 11. Train loss: 2.9024720191955566
#
# ----
# Train Acc on Epoch 58: 0.201
# Test Acc on Epoch 58: 0.136
# ----
# Epoch 59, Batch 0. Train loss: 2.871199369430542
# Epoch 59, Batch 5. Train loss: 2.849565029144287
# Epoch 59, Batch 10. Train loss: 2.9309542179107666
# Epoch 59, Batch 15. Train loss: 2.8806426525115967
#
# ----
# Train Acc on Epoch 59: 0.206
# Test Acc on Epoch 59: 0.139
# ----
# Epoch 60, Batch 4. Train loss: 2.8610525131225586
# Epoch 60, Batch 9. Train loss: 2.874868154525757
# Epoch 60, Batch 14. Train loss: 2.8708767890930176
#
# ----
# Train Acc on Epoch 60: 0.209
# Test Acc on Epoch 60: 0.139
# ----
# Epoch 61, Batch 3. Train loss: 2.8493857383728027
# Epoch 61, Batch 8. Train loss: 2.794886827468872
# Epoch 61, Batch 13. Train loss: 2.933084011077881
#
# ----
# Train Acc on Epoch 61: 0.211
# Test Acc on Epoch 61: 0.14
# ----
# Epoch 62, Batch 2. Train loss: 2.8760955333709717
# Epoch 62, Batch 7. Train loss: 2.8741304874420166
# Epoch 62, Batch 12. Train loss: 2.8567261695861816
#
# ----
# Train Acc on Epoch 62: 0.212
# Test Acc on Epoch 62: 0.14
# ----
# Epoch 63, Batch 1. Train loss: 2.955536365509033
# Epoch 63, Batch 6. Train loss: 2.8685057163238525
# Epoch 63, Batch 11. Train loss: 2.894228219985962
#
# ----
# Train Acc on Epoch 63: 0.213
# Test Acc on Epoch 63: 0.143
# ----
# Epoch 64, Batch 0. Train loss: 2.855631113052368
# Epoch 64, Batch 5. Train loss: 2.8456621170043945
# Epoch 64, Batch 10. Train loss: 2.92856502532959
# Epoch 64, Batch 15. Train loss: 2.8757987022399902
#
# ----
# Train Acc on Epoch 64: 0.214
# Test Acc on Epoch 64: 0.14
# ----
# Epoch 65, Batch 4. Train loss: 2.859130382537842
# Epoch 65, Batch 9. Train loss: 2.873112916946411
# Epoch 65, Batch 14. Train loss: 2.868617296218872
#
# ----
# Train Acc on Epoch 65: 0.215
# Test Acc on Epoch 65: 0.143
# ----
# Epoch 66, Batch 3. Train loss: 2.8427698612213135
# Epoch 66, Batch 8. Train loss: 2.7936151027679443
# Epoch 66, Batch 13. Train loss: 2.9281539916992188
#
# ----
# Train Acc on Epoch 66: 0.215
# Test Acc on Epoch 66: 0.143
# ----
# Epoch 67, Batch 2. Train loss: 2.8598344326019287
# Epoch 67, Batch 7. Train loss: 2.8761494159698486
# Epoch 67, Batch 12. Train loss: 2.870392084121704
#
# ----
# Train Acc on Epoch 67: 0.213
# Test Acc on Epoch 67: 0.141
# ----
# Epoch 68, Batch 1. Train loss: 2.950232982635498
# Epoch 68, Batch 6. Train loss: 2.865419626235962
# Epoch 68, Batch 11. Train loss: 2.89621639251709
#
# ----
# Train Acc on Epoch 68: 0.21
# Test Acc on Epoch 68: 0.145
# ----
# Epoch 69, Batch 0. Train loss: 2.835282325744629
# Epoch 69, Batch 5. Train loss: 2.8454973697662354
# Epoch 69, Batch 10. Train loss: 2.9299232959747314
# Epoch 69, Batch 15. Train loss: 2.924117088317871
#
# ----
# Train Acc on Epoch 69: 0.186
# Test Acc on Epoch 69: 0.136
# ----
# Epoch 70, Batch 4. Train loss: 2.8779895305633545
# Epoch 70, Batch 9. Train loss: 2.920527696609497
# Epoch 70, Batch 14. Train loss: 2.8721728324890137
#
# ----
# Train Acc on Epoch 70: 0.186
# Test Acc on Epoch 70: 0.125
# ----
# Epoch 71, Batch 3. Train loss: 2.8319969177246094
# Epoch 71, Batch 8. Train loss: 2.829378604888916
# Epoch 71, Batch 13. Train loss: 2.932147979736328
#
# ----
# Train Acc on Epoch 71: 0.186
# Test Acc on Epoch 71: 0.119
# ----
# Epoch 72, Batch 2. Train loss: 2.8590283393859863
# Epoch 72, Batch 7. Train loss: 2.8860998153686523
# Epoch 72, Batch 12. Train loss: 2.849726676940918
#
# ----
# Train Acc on Epoch 72: 0.172
# Test Acc on Epoch 72: 0.115
# ----
# Epoch 73, Batch 1. Train loss: 2.992434501647949
# Epoch 73, Batch 6. Train loss: 2.877450942993164
# Epoch 73, Batch 11. Train loss: 2.905224561691284
#
# ----
# Train Acc on Epoch 73: 0.188
# Test Acc on Epoch 73: 0.111
# ----
# Epoch 74, Batch 0. Train loss: 2.8826277256011963
# Epoch 74, Batch 5. Train loss: 2.840353488922119
# Epoch 74, Batch 10. Train loss: 2.9430880546569824
# Epoch 74, Batch 15. Train loss: 2.8673055171966553
#
# ----
# Train Acc on Epoch 74: 0.195
# Test Acc on Epoch 74: 0.128
# ----
# Epoch 75, Batch 4. Train loss: 2.8598132133483887
# Epoch 75, Batch 9. Train loss: 2.9091784954071045
# Epoch 75, Batch 14. Train loss: 2.8486337661743164
#
# ----
# Train Acc on Epoch 75: 0.208
# Test Acc on Epoch 75: 0.131
# ----
# Epoch 76, Batch 3. Train loss: 2.8436617851257324
# Epoch 76, Batch 8. Train loss: 2.8121337890625
# Epoch 76, Batch 13. Train loss: 2.9242141246795654
#
# ----
# Train Acc on Epoch 76: 0.201
# Test Acc on Epoch 76: 0.146
# ----
# Epoch 77, Batch 2. Train loss: 2.8737921714782715
# Epoch 77, Batch 7. Train loss: 2.889509439468384
# Epoch 77, Batch 12. Train loss: 2.8622190952301025
#
# ----
# Train Acc on Epoch 77: 0.203
# Test Acc on Epoch 77: 0.134
# ----
# Epoch 78, Batch 1. Train loss: 2.965060234069824
# Epoch 78, Batch 6. Train loss: 2.8599319458007812
# Epoch 78, Batch 11. Train loss: 2.890568494796753
#
# ----
# Train Acc on Epoch 78: 0.207
# Test Acc on Epoch 78: 0.143
# ----
# Epoch 79, Batch 0. Train loss: 2.837881088256836
# Epoch 79, Batch 5. Train loss: 2.8490495681762695
# Epoch 79, Batch 10. Train loss: 2.9276628494262695
# Epoch 79, Batch 15. Train loss: 2.8571829795837402
#
# ----
# Train Acc on Epoch 79: 0.21
# Test Acc on Epoch 79: 0.146
# ----
# Epoch 80, Batch 4. Train loss: 2.841744899749756
# Epoch 80, Batch 9. Train loss: 2.8924214839935303
# Epoch 80, Batch 14. Train loss: 2.8418686389923096
#
# ----
# Train Acc on Epoch 80: 0.214
# Test Acc on Epoch 80: 0.147
# ----
# Epoch 81, Batch 3. Train loss: 2.8286144733428955
# Epoch 81, Batch 8. Train loss: 2.8092660903930664
# Epoch 81, Batch 13. Train loss: 2.9323225021362305
#
# ----
# Train Acc on Epoch 81: 0.212
# Test Acc on Epoch 81: 0.151
# ----
# Epoch 82, Batch 2. Train loss: 2.8602421283721924
# Epoch 82, Batch 7. Train loss: 2.8795018196105957
# Epoch 82, Batch 12. Train loss: 2.85548996925354
#
# ----
# Train Acc on Epoch 82: 0.216
# Test Acc on Epoch 82: 0.152
# ----
# Epoch 83, Batch 1. Train loss: 2.9599666595458984
# Epoch 83, Batch 6. Train loss: 2.8530311584472656
# Epoch 83, Batch 11. Train loss: 2.8871631622314453
#
# ----
# Train Acc on Epoch 83: 0.213
# Test Acc on Epoch 83: 0.151
# ----
# Epoch 84, Batch 0. Train loss: 2.822765827178955
# Epoch 84, Batch 5. Train loss: 2.842376470565796
# Epoch 84, Batch 10. Train loss: 2.922330141067505
# Epoch 84, Batch 15. Train loss: 2.8715708255767822
#
# ----
# Train Acc on Epoch 84: 0.212
# Test Acc on Epoch 84: 0.152
# ----
# Epoch 85, Batch 4. Train loss: 2.8421154022216797
# Epoch 85, Batch 9. Train loss: 2.8827478885650635
# Epoch 85, Batch 14. Train loss: 2.830505132675171
#
# ----
# Train Acc on Epoch 85: 0.209
# Test Acc on Epoch 85: 0.152
# ----
# Epoch 86, Batch 3. Train loss: 2.835420608520508
# Epoch 86, Batch 8. Train loss: 2.795341730117798
# Epoch 86, Batch 13. Train loss: 2.9318504333496094
#
# ----
# Train Acc on Epoch 86: 0.211
# Test Acc on Epoch 86: 0.151
# ----
# Epoch 87, Batch 2. Train loss: 2.8608808517456055
# Epoch 87, Batch 7. Train loss: 2.8736929893493652
# Epoch 87, Batch 12. Train loss: 2.8446249961853027
#
# ----
# Train Acc on Epoch 87: 0.209
# Test Acc on Epoch 87: 0.149
# ----
# Epoch 88, Batch 1. Train loss: 2.954857349395752
# Epoch 88, Batch 6. Train loss: 2.8507745265960693
# Epoch 88, Batch 11. Train loss: 2.881260633468628
#
# ----
# Train Acc on Epoch 88: 0.215
# Test Acc on Epoch 88: 0.148
# ----
# Epoch 89, Batch 0. Train loss: 2.8122141361236572
# Epoch 89, Batch 5. Train loss: 2.8309497833251953
# Epoch 89, Batch 10. Train loss: 2.9211442470550537
# Epoch 89, Batch 15. Train loss: 2.888430118560791
#
# ----
# Train Acc on Epoch 89: 0.216
# Test Acc on Epoch 89: 0.146
# ----
# Epoch 90, Batch 4. Train loss: 2.84737491607666
# Epoch 90, Batch 9. Train loss: 2.866589307785034
# Epoch 90, Batch 14. Train loss: 2.8330109119415283
#
# ----
# Train Acc on Epoch 90: 0.221
# Test Acc on Epoch 90: 0.147
# ----
# Epoch 91, Batch 3. Train loss: 2.823986530303955
# Epoch 91, Batch 8. Train loss: 2.778085947036743
# Epoch 91, Batch 13. Train loss: 2.9277853965759277
#
# ----
# Train Acc on Epoch 91: 0.223
# Test Acc on Epoch 91: 0.145
# ----
# Epoch 92, Batch 2. Train loss: 2.849900484085083
# Epoch 92, Batch 7. Train loss: 2.867384433746338
# Epoch 92, Batch 12. Train loss: 2.843667507171631
#
# ----
# Train Acc on Epoch 92: 0.224
# Test Acc on Epoch 92: 0.145
# ----
# Epoch 93, Batch 1. Train loss: 2.9422507286071777
# Epoch 93, Batch 6. Train loss: 2.8451435565948486
# Epoch 93, Batch 11. Train loss: 2.874879837036133
#
# ----
# Train Acc on Epoch 93: 0.224
# Test Acc on Epoch 93: 0.145
# ----
# Epoch 94, Batch 0. Train loss: 2.809361457824707
# Epoch 94, Batch 5. Train loss: 2.8285858631134033
# Epoch 94, Batch 10. Train loss: 2.9147839546203613
# Epoch 94, Batch 15. Train loss: 2.875566244125366
#
# ----
# Train Acc on Epoch 94: 0.225
# Test Acc on Epoch 94: 0.146
# ----
# Epoch 95, Batch 4. Train loss: 2.8371245861053467
# Epoch 95, Batch 9. Train loss: 2.8572278022766113
# Epoch 95, Batch 14. Train loss: 2.824712038040161
#
# ----
# Train Acc on Epoch 95: 0.227
# Test Acc on Epoch 95: 0.147
# ----
# Epoch 96, Batch 3. Train loss: 2.820505380630493
# Epoch 96, Batch 8. Train loss: 2.76749324798584
# Epoch 96, Batch 13. Train loss: 2.925421953201294
#
# ----
# Train Acc on Epoch 96: 0.231
# Test Acc on Epoch 96: 0.148
# ----
# Epoch 97, Batch 2. Train loss: 2.836585760116577
# Epoch 97, Batch 7. Train loss: 2.864104747772217
# Epoch 97, Batch 12. Train loss: 2.8390135765075684
#
# ----
# Train Acc on Epoch 97: 0.233
# Test Acc on Epoch 97: 0.148
# ----
# Epoch 98, Batch 1. Train loss: 2.936875343322754
# Epoch 98, Batch 6. Train loss: 2.8426780700683594
# Epoch 98, Batch 11. Train loss: 2.8720455169677734
#
# ----
# Train Acc on Epoch 98: 0.236
# Test Acc on Epoch 98: 0.148
# ----
# Epoch 99, Batch 0. Train loss: 2.8056867122650146
# Epoch 99, Batch 5. Train loss: 2.8249940872192383
# Epoch 99, Batch 10. Train loss: 2.9106357097625732
# Epoch 99, Batch 15. Train loss: 2.8666610717773438
#
# ----
# Train Acc on Epoch 99: 0.241
# Test Acc on Epoch 99: 0.147
# ----
